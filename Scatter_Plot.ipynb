# %% [markdown]
# # Seaborn scatterplot

# %%
# importing all required Libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# reading the Dataset
df7 = sns.load_dataset('mpg').dropna()

# %%
df7
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# total no:of Rows and Columns in a DF
df7.shape
# Out:
# (392, 9)

# %%
# all column names in a DataFrame
df7.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# Top 5 Records
df7.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Bottom 5 Records
df7.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
# gives all the information of the DF
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
# it returns the description of the data in a DF
df7.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
# returns a Series that contain counts of unique values
df7.mpg.value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: mpg, Length: 127, dtype: int64

# %%
# returns a Series that contain counts of unique values
df7.horsepower.value_counts()
# Out:
# 150.0    22
# 90.0     20
# 88.0     19
# 110.0    18
# 100.0    17
#          ..
# 61.0      1
# 93.0      1
# 148.0     1
# 152.0     1
# 82.0      1
# Name: horsepower, Length: 93, dtype: int64

# %%
# returns a Series that contain counts of unique values
df7.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
# minimum mpg value
df7.mpg.min()
# Out:
# 9.0

# %%
# maximum mpg value
df7.mpg.max()
# Out:
# 46.6

# %%
# minimum horsepower value in a horsepower column
df7.horsepower.min()
# Out:
# 46.0

# %%
# maximum horsepower value in a horsepower column
df7.horsepower.max()
# Out:
# 230.0

# %%
# minimum cylinders value
df7.cylinders.min()
# Out:
# 3

# %%
# maximum cylinders value
df7.cylinders.max()
# Out:
# 8

# %%
np.mean(df7.displacement)
# Out:
# 194.41198979591837

# %% [markdown]
#                 or

# %%
df7.displacement.mean()
# Out:
# 194.41198979591837

# %% [markdown]
# # Bivariate Analysis:

# %%
sns.set_style('dark')

# %%
sns.scatterplot(df7.mpg, df7.horsepower);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#           or

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', data = df7);

# %% [markdown]
#            or

# %%
sns.scatterplot(x = df7.mpg, y = df7.horsepower);

# %% [markdown]
# # Marker Styling:

# %%
sns.scatterplot(x = df7.mpg, y = df7.horsepower, s = 250, marker = '*');

# %% [markdown]
# # color, edgecolor:-

# %%
sns.scatterplot(x = df7.mpg, y = df7.horsepower, s = 250, marker = '*', color = 'y', edgecolor = 'black');

# %% [markdown]
# # Semantic Variables:

# %% [markdown]
# # hue:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'origin', data = df7);

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'origin', data = df7, palette = 'plasma');

# %% [markdown]
# # Contineous Variables:

# %% [markdown]
# # Palette:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'model_year', data = df7, 
                                                             palette= 'Accent');

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        palette = 'rainbow');

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        palette = 'PuBu',
                                                        s = 80);

# %% [markdown]
# # style:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        palette = 'nipy_spectral_r',
                                                        s = 80,
                                                        style = 'origin',
                                                        x_jitter = 0.9,
                                                        y_jitter = 0.4);

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        s = 70,
                                                        palette= 'Accent',
                                                        style = 'origin',
                                                        x_jitter = 1.2,
                                                        y_jitter = 2);

# %% [markdown]
# # size:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        s = 50,
                                                        palette= 'seismic',
                                                        style = 'origin',
                                                        x_jitter = 10,
                                                        y_jitter = 6,
                                                        size = 'cylinders');

# %% [markdown]
# # sizes:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        s = 50,
                                                        palette= 'PuOr',
                                                        style = 'origin',
                                                        x_jitter = 10,
                                                        y_jitter = 6,
                                                        size = 'cylinders',
                                                        sizes = [100,70,120,50,70]);

# %% [markdown]
# # alpha:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        s = 50,
                                                        palette= 'PiYG',
                                                        style = 'origin',
                                                        x_jitter = 10,
                                                        y_jitter = 6,
                                                        size = 'cylinders',
                                                        sizes = [200, 150, 220,80,30],
                                                        alpha = 0.9);

# %% [markdown]
# # edgecolor:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        s = 50,
                                                        palette= 'PiYG',
                                                        style = 'origin',
                                                        x_jitter = 10,
                                                        y_jitter = 6,
                                                        size = 'cylinders',
                                                        sizes = [200, 150, 220, 80, 30],
                                                        alpha = 0.9,
                                                        edgecolor = 'k');

# %% [markdown]
# # linewidth:

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                                                        s = 50,
                                                        palette= 'PiYG',
                                                        style = 'origin',
                                                        x_jitter = 10,
                                                        y_jitter = 6,
                                                        size = 'cylinders',
                                                        sizes = [200, 150, 220, 80, 30],
                                                        alpha = 0.9,
                                                        edgecolor = 'k',
                                                        linewidth = 0.8);

# %%
sns.scatterplot(x = 'mpg', y = 'horsepower', hue = 'cylinders', data = df7, 
                             style = 'cylinders',  
                             s = 200, 
                             palette = 'magma_r',);
