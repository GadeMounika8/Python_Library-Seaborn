# %% [markdown]
# # Seaborn kdeplot and histplot

# %%
# importing allthe required Libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Loading the Dataset
df = sns.load_dataset('tips').dropna()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Total no:of Rows and Columns of a DataFrame
df.shape
# Out:
# (244, 7)

# %%
# All column names in a DF
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Top 5 Records
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Bottom 5 Records
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# gives all the informmation of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# returns the Description of the Data in a DF
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# minimum total_bill value
df.total_bill.min()
# Out:
# 3.07

# %%
# maximum total_bill value
df.total_bill.max()
# Out:
# 50.81

# %%
# average total_bill value
df.total_bill.mean()
# Out:
# 19.785942622950824

# %%
# median of total_bill
df.total_bill.median()
# Out:
# 17.795

# %%
# variance of total_bill
df.total_bill.var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64>

# %%
# standard deviation of total_bill
df.total_bill.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64>

# %%
# returns a Series that contain counts of unique values.
df.total_bill.value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %% [markdown]
# # Univariate Analysis(1D):

# %%
sns.set_style('darkgrid')
sns.kdeplot(df.total_bill);

# %% [markdown]
#                or

# %%
sns.set_style('darkgrid')
sns.kdeplot( x = 'total_bill', data = df);

# %%
sns.set_style('darkgrid')
sns.kdeplot( x = 'tip', data = df);

# %%
sns.set_style('darkgrid')
sns.kdeplot( x = 'size', data = df);

# %% [markdown]
# # shade:

# %%
sns.set_style('dark')
sns.kdeplot(df.total_bill, 
                shade = True);

# %% [markdown]
# # bandwidth:

# %%
sns.set_style('dark')
sns.kdeplot(df.total_bill, 
                shade = True,
                bw = 2);
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.kdeplot(df.total_bill, cumulative = True);

# %% [markdown]
# # color:

# %%
sns.set_style('dark')
sns.kdeplot(df.total_bill, 
                shade = True,
                bw = 2, 
                color = 'g'
                );
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('white')
sns.kdeplot(df.total_bill, 
                shade = True,
                cumulative = True);

# %% [markdown]
# # Bivariate Analysis(2D):

# %%
sns.set_style('white');
sns.kdeplot(df.tip, df.total_bill);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # n_levels, color:

# %%
sns.set_style('white');
sns.kdeplot(df.tip, df.total_bill, 
                    n_levels = 30,
                    color = 'grey');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # shade:

# %%
sns.set_style('white');
sns.kdeplot( df.tip, df.total_bill, 
                     n_levels = 9,
                     shade = True);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_style('dark')
sns.kdeplot( df.tip, df.total_bill, 
                     n_levels = 9,
                     shade = True,
                     color = 'olive');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_style('dark')
sns.kdeplot( df.tip, df.total_bill, 
                     n_levels = 9,
                     shade = True,
                     color = 'maroon');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # shade_lowest:

# %%
sns.set_style('white');
sns.kdeplot(df.tip, df.total_bill,
                    shade_lowest =True,
                    color = 'indigo');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\anaconda\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('white');
sns.kdeplot(df.tip, df.total_bill,
                    shade_lowest = False,
                    color = 'indigo');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\anaconda\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # cbar:

# %%
sns.set_style('dark')
sns.kdeplot(df.tip, df.total_bill,
                    shade = True,
                    shade_lowest = False,
                    cbar = True
                    );
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\anaconda\lib\site-packages\seaborn\distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0.05`, but please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Multivatiate Analysis:

# %% [markdown]
# # Histogram Plot

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.__version__
# Out:
# '0.11.2'

# %%
df = sns.load_dataset('tips').dropna()

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.total_bill.value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %% [markdown]
# # Univariate Analysis:

# %%
sns.set_style('dark')
sns.histplot( df.total_bill);

# %% [markdown]
#      or

# %%
sns.set_style('dark')
sns.histplot( x = 'total_bill', data = df);

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df);

# %%
sns.set_style('white')
sns.histplot(x = 'tip', data = df);

# %%
sns.set_style('white')
sns.histplot(x = 'size', data = df);

# %%
sns.set_style('dark')
sns.histplot(y = 'total_bill', data = df);

# %% [markdown]
# # Styling:

# %% [markdown]
# # color, kdeplot:

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                            kde = True, color = 'y');

# %% [markdown]
# # bins:

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                            kde = False,
                            bins = 15, color = 'indigo');

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                            kde = False,
                            bins = [3,10,25,35,50], color = 'olive');

# %% [markdown]
# # bindwidth:

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                            kde = False,
                            binwidth = 5, color = 'cyan');

# %% [markdown]
# # binrange:

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                            kde = True,
                            binwidth = 6,
                            binrange = (0,60), color = 'orange');

# %% [markdown]
# # Statistics:

# %% [markdown]
# # stat:

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                               stat = 'count', color = 'green');

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                               stat = 'density', color = 'purple');

# %% [markdown]
# # cumulative:

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               stat = 'probability',
                               element = 'step',
                               cumulative = False, color = 'gold');

# %%
sns.set_style('dark')
sns.histplot(x = 'total_bill', data = df,
                               stat = 'probability',
                               fill = False,
                               element = 'step',
                               cumulative = False, color = 'k');

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               stat = 'probability',
                               fill = True,
                               element = 'step',
                               cumulative = True, color = 'violet');

# %% [markdown]
# # Bivariate Analysis of Histplot:

# %%
sns.set_style('white')

# %%
sns.histplot(y = 'total_bill', x = 'day', data = df);

# %%
sns.histplot(y = 'total_bill', x = 'day', data = df, cbar = True);

# %%
sns.histplot(x = 'total_bill', y = 'tip', data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # cbar:

# %%
sns.histplot(x = 'total_bill', y = 'tip', data = df, cbar = True);

# %% [markdown]
# # palette, hue:-

# %%
sns.histplot(x = 'total_bill', y = 'tip', data = df, hue = 'day', palette = 'Accent')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Discrete color map:

# %%
sns.histplot(y = 'total_bill', x = 'day', data = df, hue = 'day', palette = 'Accent')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(x = 'total_bill', y = 'day', data = df, hue = 'day', palette = 'Accent')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %% [markdown]
# # Categorical Variables:

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # hue:

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex');

# %% [markdown]
# # element:

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex',
                               element = 'step');

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex',
                               element = 'poly');

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex',
                               element = 'poly',
                               multiple = 'layer');

# %% [markdown]
# # multiple:

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex',
                               element = 'poly',
                               multiple = 'stack');

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex',
                               element = 'poly',
                               multiple = 'fill');

# %%
sns.set_style('white')
sns.histplot(x = 'total_bill', data = df,
                               hue = 'sex',
                               element = 'poly',
                               multiple = 'dodge');

# %% [markdown]
# # Styling:

# %% [markdown]
# # shrink:

# %%
sns.histplot(x = 'day', hue = 'sex', multiple = 'dodge', data = df,shrink = 0.8);

# %%
sns.histplot(x = 'day', hue = 'sex', multiple = 'dodge', data = df, shrink = 0.3);

# %% [markdown]
# # palette:

# %%
sns.histplot(x = 'day', hue = 'sex', multiple = 'dodge', data = df,shrink = 0.3, palette = 'plasma');
