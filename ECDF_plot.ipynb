# %% [markdown]
# # Seaborn ecdfplot

# %%
# importing all the required libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# reading the dataset
df1 = sns.load_dataset('tips').dropna()

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# shows total no:of Rows and Columns
df1.shape
# Out:
# (244, 7)

# %%
# displays all the column names in a DataFrame
df1.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Top 5 Records
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# minimum value in a total_bill column of a DF
df1.total_bill.min()
# Out:
# 3.07

# %%
# maximum value in a total_bill column of a DF
df1.total_bill.max()
# Out:
# 50.81

# %%
# returns a Series that contain counts of unique values.
df1.total_bill.value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
# returns a Series that contain counts of unique values and get top 30 records
df1.total_bill.value_counts().head(30)
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
# 13.00    2
# 10.33    2
# 15.69    2
# 7.25     2
# 18.29    2
# 20.29    2
# 10.34    2
# 20.69    2
# 21.01    2
# 17.51    1
# 21.50    1
# 16.49    1
# 13.39    1
# 25.00    1
# 16.21    1
# 48.17    1
# 12.66    1
# 20.76    1
# 24.52    1
# 19.77    1
# 31.71    1
# 10.59    1
# 10.63    1
# 50.81    1
# 15.81    1
# Name: total_bill, dtype: int64

# %%
# median of total_bill
df1.total_bill.median()
# Out:
# 17.795

# %%
# variance of total_bill
df1.total_bill.var
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.var of 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64>

# %%
# gives all the information of the DF
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# it returns description of the data in a DF
df1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Univariate Analysis:

# %%
sns.set_style('white')

# %% [markdown]
# # X - axis:

# %%
sns.ecdfplot(x = 'total_bill', data = df1);

# %%
df1.total_bill.min()
# Out:
# 3.07

# %%
df1.total_bill.max()
# Out:
# 50.81

# %%
df1.total_bill.value_counts().head()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
# Name: total_bill, dtype: int64

# %% [markdown]
#      or

# %%
sns.ecdfplot(df1.total_bill);

# %%
sns.ecdfplot(df1.total_bill)
plt.axvline(30, c= 'k')

# %% [markdown]
# # Y - axis:

# %%
sns.ecdfplot(y = 'total_bill', data = df1)
# Out:
# <AxesSubplot:xlabel='Proportion', ylabel='total_bill'>

# %%
sns.ecdfplot(y = 'total_bill', data = df1)
plt.axvline(0.5, c = 'k')

# %%
df1.total_bill.median()
# Out:
# 17.795

# %% [markdown]
# # Additional Options:

# %% [markdown]
# # color & count:

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               stat = 'count',
                               color = 'indigo')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               stat = 'count',
                               color = 'gold')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# # Ranking with count and complementary:

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               stat = 'count',
                               complementary = True,
                               color = 'black');

# %% [markdown]
# # weights:

# %%
sns.ecdfplot(x= 'total_bill', data = df1, 
                     weights = 'total_bill', 
                     color = 'olive');
plt.axvline(0.4, c = 'red');

# %% [markdown]
# # Styling:

# %% [markdown]
# # color:

# %%
sns.ecdfplot(x = 'tip', data = df1, 
                  color = 'cyan');

# %%
sns.ecdfplot(x = 'size', data = df1, 
                    color = 'purple');

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # hue:

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = "sex");

# %% [markdown]
# # palette:

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = "time",
                               palette = 'BuGn');

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = "day",
                               palette = 'twilight');

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = "smoker",
                               palette = 'PuBu');

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               stat = 'count',
                               hue = 'day',
                               palette = 'rainbow');

# %%
sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = 'day',
                               palette = 'ocean');

# %% [markdown]
# # linewidth:

# %%
x = sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = 'day',
                               palette = 'CMRmap',
                               lw = 1);

# %%
type(x)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %% [markdown]
# # Adjust Legend:

# %%
x.legend(['Thursday', 'Friday', 'Saturday', 'Sunday'],title = 'day of the week',loc = 4)
plt.show()

# %%
x = sns.ecdfplot(x = 'total_bill', data = df1,
                               hue = 'day',
                               palette = 'Dark2',
                               lw = 1);

# %%
type(x)
# Out:
# matplotlib.axes._subplots.AxesSubplot
