# %% [markdown]
# # Seaborn stripplot

# %%
# importing all required Libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# load the dataset
df6 = sns.load_dataset('mpg').dropna()

# %%
df6
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# total no:of Rows and Columns
df6.shape
# Out:
# (392, 9)

# %%
# all column names in a DataFrame
df6.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# top 5 Records
df6.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# Bottom 5 Records
df6.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
# returns a Series that contain counts of unique values
df6.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
# gives all the information of the DF
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
# it returns the description of the data in a DF
df6.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
df6 = df6[df6.cylinders.isin([1,2,3,4,5,6,7,8,9])]

# %% [markdown]
# # Univariate Analysis:

# %%
sns.set_style('white')

# %%
sns.stripplot(df6.horsepower);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#              or

# %%
sns.stripplot(x = 'horsepower', data = df6);

# %%
sns.stripplot(y = 'mpg', data = df6);

# %%
sns.stripplot(y = 'displacement', data = df6);

# %%
sns.stripplot(y = 'acceleration', data = df6);

# %%
sns.stripplot(y = 'weight', data = df6);

# %% [markdown]
# # Bivariate Analysis:

# %%
sns.set_style('white')

# %% [markdown]
# # Orientaton:

# %%
sns.stripplot(df6.origin, df6.horsepower);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
#      or

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6);

# %% [markdown]
# # Palette:

# %%
sns.stripplot(x = 'horsepower', y = 'origin', data = df6, palette = 'cool');

# %% [markdown]
#    or

# %%
sns.stripplot(df6.horsepower, df6.origin, palette = 'summer');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Orientation:

# %%
sns.stripplot(df6.origin, df6.horsepower, palette = 'spring');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # jitter:

# %%
sns.stripplot(df6.origin, df6.horsepower, jitter = False, palette = 'winter');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(df6.origin, df6.horsepower, jitter = 0.2);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from ipywidgets import interactive
def width(j = 0.2):
    sns.stripplot(df6.origin, df6.horsepower,jitter = j)
interactive(width, jitter = (0.1,0.6,0.4))
# Out:
# interactive(children=(FloatSlider(value=0.2, description='j', max=0.6000000000000001, min=-0.2), Output()), _d…

# %% [markdown]
# # alpha:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                              alpha = 0.7)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %% [markdown]
# # size:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, size = 7);

# %% [markdown]
# # linewidth:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, 
                                      size = 7,
                                      linewidth = 1);

# %% [markdown]
# # edgecolor:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, 
                                      size = 7,
                                      linewidth = 1,
                                      edgecolor = 'k');

# %% [markdown]
# # Marker Style:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, 
                                      size = 7,
                                      jitter = 0.2,
                                      linewidth = 1,
                                      edgecolor = 'k',
                                      marker = 'D');

# %% [markdown]
# # palette:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, 
                                      size = 7,
                                      jitter = 0.2,
                                      linewidth = 1,
                                      edgecolor = 'k',
                                      marker = 'D',
                                      palette = 'plasma');

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # hue:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, 
                                      size = 7,
                                      jitter = 0.2,
                                      linewidth = 1,
                                      edgecolor = 'k',
                                      marker = 'D',
                                      hue = 'cylinders',
                                      palette = 'Accent'
                                      );

# %% [markdown]
# # dodge:

# %%
sns.stripplot(x = 'origin', y = 'horsepower', data = df6, 
                                      alpha = 0.9, 
                                      size = 7,
                                      jitter = 0.2,
                                      linewidth = 1,
                                      edgecolor = 'k',
                                      marker = 'D',
                                      hue = 'cylinders',
                                      palette = 'PiYG',
                                      dodge = True
                                      );

# %%
sns.stripplot(x = 'origin', y = 'horsepower', hue = 'model_year', data = df6, )
plt.legend(loc = 1);

# %%
sns.stripplot(x = 'origin', y = 'horsepower', hue = 'model_year', data = df6,
                                                       dodge = True)
plt.legend(loc = 1);

# %%
sns.stripplot(x = 'origin', y = 'horsepower', hue = 'cylinders', data = df6,
                                                palette = 'rainbow')
plt.legend(loc = 1)

# %%
sns.stripplot(x = 'origin', y = 'horsepower', hue = 'cylinders', data = df6,
                                              dodge = True,
                                              palette = 'cubehelix',orient = 'h')
plt.legend(loc = 1);
