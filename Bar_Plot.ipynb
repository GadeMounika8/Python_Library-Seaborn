# %% [markdown]
# # Seaborn Barplot

# %%
# importing all the required libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# reading the Dataset
df10 = sns.load_dataset('tips').dropna()

# %%
df10
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# shows the total number of Rows and Columns
df10.shape
# Out:
# (244, 7)

# %%
# shows all the column names in a DataFrame
df10.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# Displays Top 10 Records in a Dataset
df10.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# Displays Bottom 5 Records in a Dataset
df10.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# shows all the information about the DataFrame
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# it returns description of all the Numerical Variables in a Dataset
df10.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# it counts unique values of tip column
df10.tip.value_counts()
# Out:
# 2.00    33
# 3.00    23
# 4.00    12
# 5.00    10
# 2.50    10
#         ..
# 4.34     1
# 1.56     1
# 5.20     1
# 2.60     1
# 1.75     1
# Name: tip, Length: 123, dtype: int64

# %%
df10.groupby('day').tip.mean()
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
df10.groupby('day').tip.min()
# Out:
# day
# Thur    1.25
# Fri     1.00
# Sat     1.00
# Sun     1.01
# Name: tip, dtype: float64

# %%
df10.groupby('day').tip.max()
# Out:
# day
# Thur     6.70
# Fri      4.73
# Sat     10.00
# Sun      6.50
# Name: tip, dtype: float64

# %%
df10.groupby('day').tip.count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: tip, dtype: int64

# %% [markdown]
# # Bivariate Analysis:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                   palette = 'PiYG_r');

# %%
df10.groupby('day').tip.mean()
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %% [markdown]
#                        or

# %%
sns.barplot(x = df10.day, y = df10.tip,
                           palette = 'PiYG_r');

# %% [markdown]
#                           or

# %%
sns.barplot(x = 'day', y = 'tip', data = df10,
                                 palette = 'PiYG_r');

# %% [markdown]
#                       or

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                 ci = 95,
                                  palette = 'PiYG_r');

# %% [markdown]
# # Horizontal Barplot:

# %% [markdown]
# # Palette Parameter:

# %%
sns.barplot(x = 'tip',y = 'day', data= df10,
                            palette = 'cool');

# %% [markdown]
# # Confidence Interval Parameter(ci):

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                 ci = 60, 
                                 palette = 'winter');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                 ci = None,
                                 palette = 'spring');

# %%
df10.groupby('day').tip.describe()
# Out:
#       count      mean       std   min     25%    50%     75%    max
# day
# Thur   62.0  2.771452  1.240223  1.25  2.0000  2.305  3.3625   6.70
# Fri    19.0  2.734737  1.019577  1.00  1.9600  3.000  3.3650   4.73
# Sat    87.0  2.993103  1.631014  1.00  2.0000  2.750  3.3700  10.00
# Sun    76.0  3.255132  1.234880  1.01  2.0375  3.150  4.0000   6.50

# %% [markdown]
# # Estimator Parameter:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                     ci = 95, 
                                     estimator = np.min,
                                     palette = 'ocean');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                     ci = 95, 
                                     estimator = np.max,
                                     palette = 'flare');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                     ci = 95, 
                                     estimator = np.std,
                                     palette = 'viridis');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                     ci = 95, 
                                     estimator = np.mean,
                                     palette = 'Dark2');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10,
                                 ci = 95, 
                                 estimator = np.median,
                                 palette = 'plasma'
                                 );

# %% [markdown]
# # Category Variables:

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # Horizontal Barplot:

# %% [markdown]
# # hue:

# %%
sns.barplot(x = 'tip', y = 'day', data= df10, 
                                  hue = 'sex',
                                  );

# %% [markdown]
# # Styling Colors:

# %% [markdown]
# # color:

# %%
sns.barplot(x = 'tip', y = 'day', data= df10, 
                                  hue = 'sex',
                                  color = 'gold');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  color = 'brown');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'smoker',
                                  color = 'cyan');

# %% [markdown]
# # order:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  color = 'purple');

# %% [markdown]
# # hue_order:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  color = 'olive');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  color = 'c');

# %% [markdown]
# # errcolor:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  color = 'y',
                                  errcolor = 'grey');

# %% [markdown]
# # errwidth:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  color = 'purple',
                                  errcolor = 'k',
                                  errwidth = 1.6);

# %% [markdown]
# # palette:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  errcolor = 'k',
                                  errwidth = 1.6,
                                  palette = 'winter');

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  errcolor = 'k',
                                  errwidth = 1.6,
                                  palette = 'summer');

# %% [markdown]
# # edgecolor:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  errcolor = 'k',
                                  errwidth = 1.6,
                                  palette = 'Accent',
                                  edgecolor = 'mediumblue');

# %% [markdown]
# # linewidth:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  errcolor = 'k',
                                  errwidth = 1.6,
                                  palette = 'rainbow',
                                  edgecolor = 'maroon',
                                  linewidth = '1.2',
                                  );

# %% [markdown]
# # dodge:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  errcolor = 'k',
                                  errwidth = 1.6,
                                  palette = 'rainbow',
                                  edgecolor = 'maroon',
                                  linewidth = '1.2',
                                  dodge = False);

# %% [markdown]
# # capsize:

# %%
sns.barplot(x = 'day', y = 'tip', data= df10, 
                                  hue = 'sex',
                                  order = ['Sun', 'Sat', 'Fri', 'Thur'],
                                  hue_order = ['Female', 'Male'],
                                  errcolor = 'k',
                                  errwidth = 1.6,
                                  palette = 'rainbow_r',
                                  edgecolor = 'k',
                                  linewidth = '1.2',
                                  dodge = True,
                                  capsize =0.1);
