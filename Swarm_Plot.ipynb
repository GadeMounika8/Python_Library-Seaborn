# %% [markdown]
# # Seaborn swarmplot

# %%
# importing all required Libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# load the Dataset
df5 = sns.load_dataset('penguins').dropna()

# %%
df5
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# total number of Rows and Columns
df5.shape
# Out:
# (333, 7)

# %%
# all column names
df5.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# Top 5 Records in a DF
df5.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# Bottom 5 Records in a DF
df5.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
# gives all the information of the DF
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
# returns the Description of the Data in a DF
df5.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# returns a Series that contain counts of unique values
df5.bill_depth_mm.value_counts()
# Out:
# 17.0    12
# 18.5    10
# 18.6    10
# 17.9    10
# 15.0    10
#         ..
# 20.1     1
# 20.6     1
# 14.9     1
# 13.2     1
# 20.8     1
# Name: bill_depth_mm, Length: 79, dtype: int64

# %%
# minimum value
df5.bill_depth_mm.min()
# Out:
# 13.1

# %%
# maximum value
df5.bill_depth_mm.max()
# Out:
# 21.5

# %% [markdown]
# # Univariate analysis:

# %%
sns.set_style('white')

# %%
plt.figure(figsize=(6,5))
sns.swarmplot(df5.bill_depth_mm);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # color:

# %%
plt.figure(figsize=(6,5))
sns.swarmplot(df5.bill_depth_mm, color = 'purple');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Marker:

# %%
sns.swarmplot(df5.flipper_length_mm, color = 'g', marker = 'D')
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='flipper_length_mm'>

# %%
sns.swarmplot(df5.body_mass_g, color = 'indigo', marker = '*');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # linewidth:

# %%
sns.swarmplot(df5.bill_depth_mm, linewidth = 1);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # edgecolor:

# %%
sns.swarmplot(df5.bill_depth_mm, linewidth = 1, edgecolor = 'k');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # linewidth, edgecolor, marker:

# %%
sns.swarmplot(df5.bill_depth_mm, linewidth = 1, edgecolor = 'r', marker = '*');
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Bivariate Analysis:

# %%
sns.swarmplot(x = df5.species, y = df5.bill_length_mm);

# %% [markdown]
# # palette:

# %%
sns.swarmplot(x = df5.species, y = df5.bill_length_mm, palette = 'summer');

# %%
sns.swarmplot(x = 'island', y = 'bill_length_mm', data = df5,
                                 palette = 'magma')
# Out:
# <AxesSubplot:xlabel='island', ylabel='bill_length_mm'>

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # hue:

# %%
sns.swarmplot(x = 'species', y = 'bill_length_mm',
                               hue = 'sex',
                               data = df5,
                               palette = 'winter')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# # dodge:

# %%
sns.swarmplot(x = 'species', y = 'bill_length_mm',
                               data = df5,
                               hue = 'sex',
                               dodge = True,
                               palette = 'Dark2');
# Out:
# C:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = 'species', y = 'bill_length_mm',
                               hue = 'island',
                               data = df5,
                               palette = 'BuPu')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.swarmplot(x = 'species', y = 'bill_length_mm',
                               hue = 'island',
                               data = df5,
                               palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# # edgecolor, linewidth:

# %%
sns.swarmplot(x = 'species', y = 'bill_length_mm',
                               hue = 'island',
                               data = df5,
                               palette = 'viridis',
                               edgecolor = 'k',
                               linewidth = 0.4)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# # size:

# %%
sns.swarmplot(x = 'species', y = 'bill_length_mm',
                               hue = 'island',
                               data = df5,
                               palette = 'rocket',
                               edgecolor = 'k',
                               linewidth = 0.4,
                               size = 6
                               )
# Out:
# C:\anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %% [markdown]
# # with boxplot:

# %%
sns.boxplot(x = 'species', y = 'bill_length_mm', data = df5)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5);

# %%
sns.boxplot(x = 'species', y = 'bill_length_mm', data = df5)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k');

# %%
sns.boxplot(x = 'species', y = 'bill_length_mm', data = df5, palette = 'PiYG')
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.8);

# %%
sns.boxplot(x = 'species', y = 'bill_length_mm', data = df5, palette = 'PiYG', whis = np.inf)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.8);

# %% [markdown]
# # with violinplot:

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5);

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k');

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5, palette = 'BuGn')
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.7);

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5, palette = 'BuGn', scale = 'width')
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.7);

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5, palette = 'BuGn', scale = 'width')
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.7, size = 4);

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5, palette = 'BuGn', scale = 'width', inner = None)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.7, size = 5);

# %%
sns.violinplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'cyan', scale = 'width', inner = None)
sns.swarmplot(x = 'species', y = 'bill_length_mm', data = df5, color = 'k', alpha = 0.7, size = 5);
