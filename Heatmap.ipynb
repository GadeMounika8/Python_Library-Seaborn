# %% [markdown]
# # Seaborn Heatmap

# %%
# importing all the required libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# reading the Dataset
df8 = sns.load_dataset('penguins').dropna()

# %%
df8
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# shows the total no:of Rows and Columns
df8.shape
# Out:
# (333, 7)

# %%
# Displays all the column names in a DF
df8.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
# Top 5 Records in a Df
df8.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
# Bottom 5 Records in a DF
df8.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
# gives all the information of the DF
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
# it returns the description of the data in a DataFrame
df8.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df8.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
sns.heatmap(df8.corr());

# %% [markdown]
# # Color Palette:

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu');

# %% [markdown]
# # Controlling the colorbar: center:-

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0);

# %% [markdown]
# # Controling the colorbar: vmin, vmax

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1);

# %% [markdown]
# # Annotations:

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True);

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True);

# %% [markdown]
# # fmt:

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                     fmt = ".1f");

# %% [markdown]
# # annot_kws:

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     });

# %% [markdown]
# # Styling:

# %% [markdown]
# # linewidth:

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.2);

# %% [markdown]
# # linecolor:

# %%
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w');

# %% [markdown]
# # xticklables, yticklables:

# %%
labels = ['Bill_Length_mm', 'Bill_Depth_mm', 'Flipper_Length_mm', 'Body_Mass_g']
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w',
                                                                     xticklabels = labels, 
                                                                     yticklabels = labels);

# %%
labels = ['Bill_Length_mm', 'Bill_Depth_mm', 'Flipper_Length_mm', 'Body_Mass_g']
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w',
                                                                     xticklabels = False, 
                                                                     yticklabels = labels);

# %%
labels = ['Bill_Length_mm', 'Bill_Depth_mm', 'Flipper_Length_mm', 'Body_Mass_g']
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w',
                                                                     xticklabels = labels, 
                                                                     yticklabels = False);

# %%
labels = ['Bill_Length_mm', 'Bill_Depth_mm', 'Flipper_Length_mm', 'Body_Mass_g']
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w',
                                                                     xticklabels = False, 
                                                                     yticklabels = False);

# %% [markdown]
# # square:

# %%
labels = ['Bill_Length_mm', 'Bill_Depth_mm', 'Flipper_Length_mm', 'Body_Mass_g']
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0.1,
                                                                     linecolor = 'w',
                                                                     xticklabels = True, 
                                                                     yticklabels = True,
                                                                     square = True);

# %%
labels = ['Bill_Length_mm', 'Bill_Depth_mm', 'Flipper_Length_mm', 'Body_Mass_g']
sns.heatmap(df8.corr(), cmap = 'RdPu',center = 0, vmin = -1, vmax = 1, annot = True,
                                                                    fmt = ".2f", annot_kws = {
                                                                    'fontsize':12,
                                                                    'fontweight':'bold',
                                                                    'fontfamily':'Times new roman',
                                                                    'color':'w'
                                                                     },
                                                                     linewidth = 0,
                                                                     linecolor = 'w',
                                                                     xticklabels = True, 
                                                                     yticklabels = True,
                                                                     square = True);
