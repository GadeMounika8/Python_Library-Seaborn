# %% [markdown]
# # Seabornviolinplot

# %%
# importing all required libraries
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# reading the Dataset
df4 = sns.load_dataset('mpg').dropna()

# %%
df4
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# total no:of Rows and Columns of the DataFrame
df4.shape
# Out:
# (392, 9)

# %%
# Top 5 Records
df4.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# all column names in a DF
df4.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# returns a Series that contain counts of unique values
df4.mpg.value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: mpg, Length: 127, dtype: int64

# %%
# gives all the information of the DF
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   model_year    392 non-null    int64
#  7   origin        392 non-null    object
#  8   name          392 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 30.6+ KB

# %%
# it returns the Description of the Data in a DF
df4.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %%
# returns a Series that contain counts of unique values
df4.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
# returns a Series that contain counts of unique values
df4.mpg.value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: mpg, Length: 127, dtype: int64

# %%
# returns a Series that contain counts of unique values
df4.horsepower.value_counts()
# Out:
# 150.0    22
# 90.0     20
# 88.0     19
# 110.0    18
# 100.0    17
#          ..
# 61.0      1
# 93.0      1
# 148.0     1
# 152.0     1
# 82.0      1
# Name: horsepower, Length: 93, dtype: int64

# %%
# returns a Series that contain counts of unique values
df4.model_year.value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 75    30
# 82    30
# 70    29
# 79    29
# 72    28
# 77    28
# 81    28
# 71    27
# 80    27
# 74    26
# Name: model_year, dtype: int64

# %% [markdown]
# # Univariate Analysis:

# %%
sns.set_style('white')

# %%
sns.violinplot(df4.cylinders);
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.violinplot(y = 'mpg', data = df4)
# Out:
# <AxesSubplot:ylabel='mpg'>

# %%
sns.violinplot(y = 'horsepower', data = df4)
# Out:
# <AxesSubplot:ylabel='horsepower'>

# %%
sns.violinplot(y = 'cylinders', data = df4)
# Out:
# <AxesSubplot:ylabel='cylinders'>

# %% [markdown]
# # Bivariate Analysis:

# %%
sns.violinplot(x = df4.cylinders, y = df4.mpg);

# %%
sns.violinplot(x = df4.cylinders, y = df4.displacement);

# %%
sns.violinplot(x = df4.cylinders, y = df4.horsepower);

# %% [markdown]
# # linewidth:

# %%
sns.violinplot(x = 'cylinders', y = 'horsepower', data = df4,
                                linewidth = 1);

# %% [markdown]
# # bandwidth:

# %%
sns.violinplot(x = 'cylinders', y = 'horsepower', data = df4,
                                linewidth = 1,
                                bw = 0.3);

# %% [markdown]
# # Multivariate Analysis:

# %% [markdown]
# # palette, hue:

# %%
sns.violinplot(x = df4.cylinders, y = df4.horsepower,
                                  hue = df4.origin,
                                  palette = 'viridis');

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', data = df4,
                                                   hue = 'origin',
                                                   palette = 'spring');

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                     data = df4[df4.origin.isin(['usa', 'japan'])],
                     palette = 'rainbow')
plt.legend(loc=2);

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                    data = df4[df4.origin.isin(['usa', 'europe'])],
                    palette = 'plasma')
plt.legend(loc=2);

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan'])],
                 palette = 'Accent')
plt.legend(loc=2);

# %% [markdown]
# # split:

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan'])], 
                 split = True,
                 palette = 'CMRmap')
plt.legend(loc=2);

# %% [markdown]
# # inner:

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan'])], 
                 split = True,
                 inner = 'quartiles',
                 palette = 'BuPu')
plt.legend(loc=9);

# %% [markdown]
# # scale:

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan'])], 
                 split = True,
                 scale = 'count',
                 palette = 'flare')
plt.legend(loc=9);

# %% [markdown]
# # scale_hue:

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan'])], 
                 split = True,
                 scale = 'count',
                 scale_hue = False,
                 palette = 'Greens')
plt.legend(loc=9);

# %%
(df4[df4.origin.isin(['europe', 'japan'])].groupby('cylinders').origin.value_counts())
# Out:
# cylinders  origin
# 3          japan      4
# 4          japan     69
#            europe    61
# 5          europe     3
# 6          japan      6
#            europe     4
# Name: origin, dtype: int64

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan','usa'])],
                 palette = 'PuRd',
                 scale = 'count')
plt.legend(loc=2);

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan','usa'])], 
                 scale = 'count')
plt.legend(loc=2);

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan'])], 
                 scale = 'count',
                 scale_hue = False,
                 palette = 'BuGn')
plt.legend(loc=2);

# %%
sns.violinplot( x = 'cylinders', y = 'horsepower', hue = 'origin',
                 data = df4[df4.origin.isin(['europe', 'japan','usa'])], 
                 scale = 'count',
                 scale_hue = False,
                 linewidth = 1)
plt.legend(loc=2);

# %% [markdown]
# # Styling:

# %%
sns.violinplot(x = df4.origin, y = df4.horsepower);

# %% [markdown]
# # order:

# %%
sns.violinplot(x = df4.origin, y = df4.horsepower, order = ['europe', 'japan', 'usa']);

# %% [markdown]
# # Palette:

# %%
sns.violinplot(x = df4.origin, y = df4.horsepower, order = ['europe', 'japan', 'usa'], palette = 'plasma');

# %% [markdown]
# # linewidth:

# %%
sns.violinplot(x = df4.origin, y = df4.horsepower, order = ['europe', 'japan', 'usa'], linewidth = 2, palette = 'plasma');

# %% [markdown]
# # KDE options:

# %%
sns.violinplot(x = df4.origin, y = df4.horsepower, order = ['europe', 'japan', 'usa'], linewidth = 2, palette = 'winter', bw = 0.3);
